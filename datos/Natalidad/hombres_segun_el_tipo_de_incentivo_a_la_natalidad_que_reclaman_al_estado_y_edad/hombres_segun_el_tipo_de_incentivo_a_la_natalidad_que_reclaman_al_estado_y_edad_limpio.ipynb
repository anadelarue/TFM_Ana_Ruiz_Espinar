# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df_sucio = pd.read_csv('hombres_segun_el_tipo_de_incentivo_a_la_natalidad_que_reclaman_al_estado_y_edad.csv', encoding = 'latin1', sep = ';')

# %%
df_sucio
# Out:
#                 Edad                                  Tipo de incentivo  Total
# 0   Menos de 30 años  Aumento de la duración del permiso de maternid...  12,73
# 1   Menos de 30 años  Equiparación de la duración del permiso de pat...   9,43
# 2   Menos de 30 años  Más escuelas infantiles asequibles y de calida...   5,14
# 3   Menos de 30 años  Una asignación para las familias con hijos a c...   8,97
# 4   Menos de 30 años  Una asignación universal en el nacimiento de c...   6,11
# 5   Menos de 30 años  Una asignación en función de la renta en el na...   7,13
# 6   Menos de 30 años  Una asignación para las madres o padres que de...   3,45
# 7   Menos de 30 años  Servicio de guardería para niños en edad escol...   2,22
# 8   Menos de 30 años  Flexibilidad en el horario de trabajo para los...  10,72
# 9   Menos de 30 años  Mejoras en las condiciones de excedencias y re...   3,32
# 10  Menos de 30 años  Campañas de concienciación para los empresario...   1,71
# ...

# %%
df_sucio['Total'] = df_sucio['Total'].map(lambda x: x.replace(',', '.')).astype(float)

# %%
df_sucio.to_csv('hombres_segun_el_tipo_de_incentivo_a_la_natalidad_que_reclaman_al_estado_y_edad_limpio.csv', index = False)

# %%
df_sucio = df_sucio[0:60]

# %%
df_sucio['Total'] = df_sucio['Total'].map(lambda x: x.replace(',', '.')).astype(float)
# Out:
# C:\Users\anabe\AppData\Local\Temp/ipykernel_6112/1268658460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Total'] = df_sucio['Total'].map(lambda x: x.replace(',', '.')).astype(float)

# %%
df_sucio_menos30 = df_sucio[0:12]
df_sucio_menos30.rename(columns = {'Total': 'Total < 30'}, inplace=True)
df_sucio_menos30.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\anabe\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_sucio_30_34 = df_sucio[12:24]
df_sucio_30_34.rename(columns = {'Total': 'Total 30 - 34'}, inplace=True)
df_sucio_30_34.reset_index(drop=True, inplace=True)

# %%
df_sucio_35_39 = df_sucio[24:36]
df_sucio_35_39.rename(columns = {'Total': 'Total 35 - 39'}, inplace=True)
df_sucio_35_39.reset_index(drop=True, inplace=True)

# %%
df_sucio_40_44 = df_sucio[36:48]
df_sucio_40_44.rename(columns = {'Total': 'Total 40 - 44'}, inplace=True)
df_sucio_40_44.reset_index(drop=True, inplace=True)

# %%
df_sucio_45_49 = df_sucio[48:]
df_sucio_45_49.rename(columns = {'Total': 'Total 45 - 49'}, inplace=True)
df_sucio_45_49.reset_index(drop=True, inplace=True)

# %%
d = pd.concat([df_sucio_menos30, df_sucio_30_34, df_sucio_35_39, df_sucio_40_44, df_sucio_45_49], axis=1, ignore_index=False)

# %%
d.insert (6, "Porcentaje 30 - 34", d['Total < 30'] - d['Total 30 - 34'])

# %%
d.insert (10, "Porcentaje 35 - 39", d['Total 30 - 34'] - d['Total 35 - 39'])

# %%
d.insert (14, "Porcentaje 40 - 44", d['Total 35 - 39'] - d['Total 40 - 44'])

# %%
d.insert (18, "Porcentaje 45 - 49", d['Total 40 - 44'] - d['Total 45 - 49'])

# %%
d
# Out:
#                 Edad                                  Tipo de incentivo  \
# 0   Menos de 30 años  Aumento de la duración del permiso de maternid...
# 1   Menos de 30 años  Equiparación de la duración del permiso de pat...
# 2   Menos de 30 años  Más escuelas infantiles asequibles y de calida...
# 3   Menos de 30 años  Una asignación para las familias con hijos a c...
# 4   Menos de 30 años  Una asignación universal en el nacimiento de c...
# 5   Menos de 30 años  Una asignación en función de la renta en el na...
# 6   Menos de 30 años  Una asignación para las madres o padres que de...
# 7   Menos de 30 años  Servicio de guardería para niños en edad escol...
# 8   Menos de 30 años  Flexibilidad en el horario de trabajo para los...
# 9   Menos de 30 años  Mejoras en las condiciones de excedencias y re...
# 10  Menos de 30 años  Campañas de concienciación para los empresario...
# 11  Menos de 30 años      No cree que la natalidad deba ser incentivada
#
# ...
