# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows", None)

# %%
df_sucio = pd.read_csv('tasa_de_riesgo_de_pobreza_por_edad_y_sexo.csv', encoding = 'latin1', sep = ';')

# %%
df_sucio
# Out:
#        Sexo             Edad  \
# 0   Hombres  De 16 a 29 años
# 1   Hombres  De 16 a 29 años
# 2   Hombres  De 16 a 29 años
# 3   Hombres  De 16 a 29 años
# 4   Hombres  De 16 a 29 años
# 5   Hombres  De 16 a 29 años
# 6   Hombres  De 16 a 29 años
# 7   Hombres  De 16 a 29 años
# 8   Hombres  De 16 a 29 años
# 9   Hombres  De 16 a 29 años
# 10  Hombres  De 16 a 29 años
# 11  Hombres  De 16 a 29 años
# 12  Hombres  De 16 a 29 años
# 13  Hombres  De 30 a 44 años
# 14  Hombres  De 30 a 44 años
# 15  Hombres  De 30 a 44 años
# 16  Hombres  De 30 a 44 años
# 17  Hombres  De 30 a 44 años
# 18  Hombres  De 30 a 44 años
# 19  Hombres  De 30 a 44 años
# 20  Hombres  De 30 a 44 años
# 21  Hombres  De 30 a 44 años
# 22  Hombres  De 30 a 44 años
# 23  Hombres  De 30 a 44 años
# 24  Hombres  De 30 a 44 años
# 25  Hombres  De 30 a 44 años
# 26  Hombres  De 45 a 64 años
# 27  Hombres  De 45 a 64 años
# 28  Hombres  De 45 a 64 años
# 29  Hombres  De 45 a 64 años
# 30  Hombres  De 45 a 64 años
# ...

# %%
df_sucio['Total'] = df_sucio['Total'].map(lambda x: x.replace(',', '.'))

# %%
df_sucio['Total'] = df_sucio['Total'].astype(float)

# %%
años = [2020]

# %%
df_sucio = df_sucio[df_sucio['Periodo'].isin(años)]

# %%
df_sucio
# Out:
#        Sexo             Edad  \
# 0   Hombres  De 16 a 29 años
# 13  Hombres  De 30 a 44 años
# 26  Hombres  De 45 a 64 años
# 39  Mujeres  De 16 a 29 años
# 52  Mujeres  De 30 a 44 años
# 65  Mujeres  De 45 a 64 años
#
#                             Tasa de riesgo de pobreza  Periodo  Total
# 0   Tasa de riesgo de pobreza (renta del año anter...     2020   22.6
# 13  Tasa de riesgo de pobreza (renta del año anter...     2020   17.6
# 26  Tasa de riesgo de pobreza (renta del año anter...     2020   19.1
# 39  Tasa de riesgo de pobreza (renta del año anter...     2020   22.8
# 52  Tasa de riesgo de pobreza (renta del año anter...     2020   21.3
# 65  Tasa de riesgo de pobreza (renta del año anter...     2020   19.3

# %%
df_sucio = df_sucio.groupby(by = ['Sexo', 'Edad'], as_index = False).mean()

# %%
df_sucio
# Out:
#       Sexo             Edad  Periodo  Total
# 0  Hombres  De 16 a 29 años   2020.0   22.6
# 1  Hombres  De 30 a 44 años   2020.0   17.6
# 2  Hombres  De 45 a 64 años   2020.0   19.1
# 3  Mujeres  De 16 a 29 años   2020.0   22.8
# 4  Mujeres  De 30 a 44 años   2020.0   21.3
# 5  Mujeres  De 45 a 64 años   2020.0   19.3
